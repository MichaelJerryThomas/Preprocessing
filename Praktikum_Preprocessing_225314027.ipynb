# %%
import pandas as pd #Mengimpor modul pandas dengan alias pd
from sklearn import preprocessing #Mengimpor modul preprocessing dari sklearn

# %%
# Membaca file CSV
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv")
df
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0           5.1         3.5          1.4         0.2     Iris-setosa
# 1           4.9         3.0          1.4         0.2     Iris-setosa
# 2           4.7         3.2          1.3         0.2     Iris-setosa
# 3           4.6         3.1          1.5         0.2     Iris-setosa
# 4             5         3.6          1.4         0.2     Iris-setosa
# ..          ...         ...          ...         ...             ...
# 142         6.7         3.0          5.2         2.3  Iris-virginica
# 143         6.3         2.5          5.0         1.9  Iris-virginica
# 144         6.5         3.0          5.2         2.0  Iris-virginica
# 145         6.2         3.4          5.4         2.3  Iris-virginica
# 146         5.9         3.0          5.1         1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
# 1. Carilah missing data dan perbaiki
# Menghitung jumlah data yang hilang untuk setiap kolom
missing_data = df.isnull().sum()
# Menampilkan pesan sebelum menangani data yang hilang
print("Missing data sebelum diatasi:")
# Menampilkan jumlah data yang hilang untuk setiap kolom
print(missing_data)
# Out:
# Missing data sebelum diatasi:
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64

# %%
# Mengisi missing data dengan nilai rata-rata dari setiap kolom
df.fillna(df.mean(), inplace=True)
# Menampilkan DataFrame setelah penggantian data yang hilang
print(df)
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0           5.1         3.5          1.4         0.2     Iris-setosa
# 1           4.9         3.0          1.4         0.2     Iris-setosa
# 2           4.7         3.2          1.3         0.2     Iris-setosa
# 3           4.6         3.1          1.5         0.2     Iris-setosa
# 4             5         3.6          1.4         0.2     Iris-setosa
# ..          ...         ...          ...         ...             ...
# 142         6.7         3.0          5.2         2.3  Iris-virginica
# 143         6.3         2.5          5.0         1.9  Iris-virginica
# 144         6.5         3.0          5.2         2.0  Iris-virginica
# 145         6.2         3.4          5.4         2.3  Iris-virginica
# 146         5.9         3.0          5.1         1.8  Iris-virginica
#
# [147 rows x 5 columns]
# ...

# %%
# 2. Carilah not available NaN data dan droping rows
# Menghapus baris yang mengandung data NaN (not available)
df.dropna(inplace=True)
# Menampilkan DataFrame setelah penghapusan baris dengan data NaN
print (df)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0       0.222222    0.625000     0.067797    0.041667        0
# 1       0.166667    0.416667     0.067797    0.041667        0
# 2       0.111111    0.500000     0.050847    0.041667        0
# 3       0.083333    0.458333     0.084746    0.041667        0
# 4       0.194444    0.666667     0.067797    0.041667        0
# ..           ...         ...          ...         ...      ...
# 142     0.666667    0.416667     0.711864    0.916667        2
# 143     0.555556    0.208333     0.677966    0.750000        2
# 144     0.611111    0.416667     0.711864    0.791667        2
# 145     0.527778    0.583333     0.745763    0.916667        2
# 146     0.444444    0.416667     0.694915    0.708333        2
#
# [146 rows x 5 columns]

# %%
# 3. Carilah duplikasi data dan perbaiki
# Mencari dan menampilkan baris-baris yang merupakan duplikat dari baris-baris sebelumnya
duplicate_rows = df[df.duplicated()]
# Menampilkan baris-baris yang merupakan duplikat sebelum diatasi
print("Duplikasi sebelum diatasi:")
print(duplicate_rows)
# Out:
# Duplikasi sebelum diatasi:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth, Species]
# Index: []

# %%
# Menghapus baris-baris yang merupakan duplikat dari baris-baris sebelumnya
df.drop_duplicates(inplace=True)
# Menampilkan DataFrame setelah penghapusan duplikasi
print (df)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0       0.222222    0.625000     0.067797    0.041667        0
# 1       0.166667    0.416667     0.067797    0.041667        0
# 2       0.111111    0.500000     0.050847    0.041667        0
# 3       0.083333    0.458333     0.084746    0.041667        0
# 4       0.194444    0.666667     0.067797    0.041667        0
# ..           ...         ...          ...         ...      ...
# 142     0.666667    0.416667     0.711864    0.916667        2
# 143     0.555556    0.208333     0.677966    0.750000        2
# 144     0.611111    0.416667     0.711864    0.791667        2
# 145     0.527778    0.583333     0.745763    0.916667        2
# 146     0.444444    0.416667     0.694915    0.708333        2
#
# [147 rows x 5 columns]

# %%
# 4. Normalisasi data menggunakan Min-Max Scaler
# Inisialisasi objek MinMaxScaler
scaler = MinMaxScaler()
# Melakukan normalisasi data menggunakan Min-Max Scaler pada kolom-kolom yang ditentukan
df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']] = scaler.fit_transform(df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']])
# Menampilkan DataFrame setelah normalisasi data
print(df)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0       0.222222    0.625000     0.067797    0.041667        0
# 1       0.166667    0.416667     0.067797    0.041667        0
# 2       0.111111    0.500000     0.050847    0.041667        0
# 3       0.083333    0.458333     0.084746    0.041667        0
# 4       0.194444    0.666667     0.067797    0.041667        0
# ..           ...         ...          ...         ...      ...
# 142     0.666667    0.416667     0.711864    0.916667        2
# 143     0.555556    0.208333     0.677966    0.750000        2
# 144     0.611111    0.416667     0.711864    0.791667        2
# 145     0.527778    0.583333     0.745763    0.916667        2
# 146     0.444444    0.416667     0.694915    0.708333        2
#
# [147 rows x 5 columns]

# %%
#5. Label Encoding ()
from sklearn.preprocessing import LabelEncoder
# Inisialisasi objek LabelEncoder
le = LabelEncoder()
# Mengkodekan label kategori dalam kolom 'Species'
df['Species'] = le.fit_transform(df['Species'])

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0     0.222222    0.625000     0.067797    0.041667        0
# 1     0.166667    0.416667     0.067797    0.041667        0
# 2     0.111111    0.500000     0.050847    0.041667        0
# 3     0.083333    0.458333     0.084746    0.041667        0
# 4     0.194444    0.666667     0.067797    0.041667        0

# %%
# Menyimpan DataFrame yang telah diproses kembali ke file CSV
df.to_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv", index=False)
